# %% [markdown]
# # Analyzing the Linear Relaxation

# %%
from _evaluation import (  # the code has been moved to a separate file
    get_sample,
    n,
    samples,
)

# %% [markdown]
# ## Getting a sample solution
#
# The following code will create a random instance and solve
#
# 1. The linear relaxation with `>=2` subtour elimination constraints
# 2. The linear relaxation with `>=1` subtour elimination constraints
# 3. The integer programming problem to get an optimal solution
#
# It will plot the solutions for you to compare and save the results in the `samples` list.
#
# In the plots, the red lines represent fractional edges, i.e., edges with a value between 0 and 1.
# The green lines represent edges where the linear relaxation and the optimal solution agree.
# The title will show the objective value of the solution or the overlap between the linear relaxation and the optimal solution.

# %%
# Run me to get a sample on linear relaxation and integral solution
get_sample()
print(f"There are now {len(samples)} samples")
# Out:
# Solving the linear relaxation with k=2
# Set parameter LogToConsole to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 201 rows, 19900 columns and 59700 nonzeros (Min)
# Model fingerprint: 0x4b7fc7c9
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.03s
# Presolved: 200 rows, 19900 columns, 39800 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.990e+04
#  Factor NZ  : 2.010e+04 (roughly 8 MB of memory)
#  Factor Ops : 2.687e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.06 seconds (0.03 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      288    9.8385000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 288 iterations and 0.07 seconds (0.04 work units)
# Optimal objective  9.838500000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 202 rows, 19900 columns and 60291 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.8385000e+03   2.000000e+00   0.000000e+00      0s
#        7    9.8775000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.877500000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 203 rows, 19900 columns and 60882 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.8775000e+03   2.000000e+00   0.000000e+00      0s
#        4    9.9005000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 4 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.900500000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 204 rows, 19900 columns and 61473 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9005000e+03   2.000000e+00   0.000000e+00      0s
#        6    9.9430000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 6 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.943000000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 205 rows, 19900 columns and 62448 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9430000e+03   2.000000e+00   0.000000e+00      0s
#        1    9.9625000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.962500000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 206 rows, 19900 columns and 63039 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9625000e+03   2.000000e+00   0.000000e+00      0s
#        1    9.9955000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.995500000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 207 rows, 19900 columns and 63630 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9955000e+03   2.000000e+00   0.000000e+00      0s
#        3    1.0001500e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.000150000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 208 rows, 19900 columns and 64414 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0001500e+04   2.000000e+00   0.000000e+00      0s
#        2    1.0012500e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.001250000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 209 rows, 19900 columns and 65005 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0012500e+04   2.000000e+00   0.000000e+00      0s
#        9    1.0038000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.003800000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 210 rows, 19900 columns and 65596 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0038000e+04   2.000000e+00   0.000000e+00      0s
#        5    1.0064500e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.006450000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211 rows, 19900 columns and 66760 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0064500e+04   2.000000e+00   0.000000e+00      0s
#        7    1.0089500e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.008950000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 212 rows, 19900 columns and 67735 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0089500e+04   2.000000e+00   0.000000e+00      0s
#        1    1.0095000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.009500000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 213 rows, 19900 columns and 69271 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0095000e+04   2.000000e+00   0.000000e+00      0s
#        1    1.0095000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.009500000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with
+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.048325000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 236 rows, 19900 columns and 107774 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0483250e+04   2.000000e+00   0.000000e+00      0s
#        1    1.0484250e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.048425000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 237 rows, 19900 columns and 113013 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0484250e+04   2.000000e+00   0.000000e+00      0s
#        1    1.0484250e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.048425000e+04
# Solving the integral problem
# Set parameter LogToConsole to value 1
# Set parameter TimeLimit to value 30
# Set parameter LazyConstraints to value 1
# Set parameter MIPGap to value 0.001
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Non-default parameters:
# TimeLimit  30
# MIPGap  0.001
# LazyConstraints  1
#
# Optimize a model with 201 rows, 19900 columns and 59700 nonzeros (Min)
# Model fingerprint: 0x7e5448f3
# Model has 19900 linear objective coefficients
# Variable types: 0 continuous, 19900 integer (19900 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# Presolve time: 0.06s
# Presolved: 201 rows, 19900 columns, 59304 nonzeros
# Variable types: 0 continuous, 19900 integer (19900 binary)
#
# Root relaxation: objective 9.838500e+03, 213 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 9838.50000    0   30          - 9838.50000      -     -    0s
#      0     0 10036.0000    0   18          - 10036.0000      -     -    0s
#      0     0 10050.5000    0   12          - 10050.5000      -     -    0s
#      0     0 10154.0000    0   18          - 10154.0000      -     -    1s
#      0     0 10164.0000    0   20          - 10164.0000      -     -    1s
#      0     0 10176.3333    0   40          - 10176.3333      -     -    1s
#      0     0 10177.3333    0   40          - 10177.3333      -     -    1s
#      0     0 10177.3333    0   40          - 10177.3333      -     -    1s
#      0     2 10240.0000    0   29          - 10240.0000      -     -    2s
#   1267  1287 10355.0000    6   12          - 10240.0000      -   4.7    5s
#   2620  2493 10771.0000   45   16          - 10508.0000      -   5.7   10s
#   2637  2505 10746.5000  117   62          - 10650.7059      -   5.7   15s
#   3128  2842 10825.0000   42   14          - 10654.4286      -   6.2   20s
#   3668  3186 10912.0000   69    6          - 10654.4286      -   6.5   25s
# * 4607  2287              39    10769.000000 10654.4286  1.06%   6.9   29s
#   4913  2155 10687.7857   31   27 10769.0000 10668.5000  0.93%   7.0   30s
#
# Cutting planes:
#   Gomory: 10
#   Lift-and-project: 15
#   Flow cover: 2
#   Zero half: 14
#   Lazy constraints: 80
#
# Explored 4976 nodes (35302 simplex iterations) in 30.03 seconds (8.74 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 1: 10769
#
# Time limit reached
# Best objective 1.076900000000e+04, best bound 1.066900000000e+04, gap 0.9286%
#
# User-callback calls 15568, time in user-callback 11.41 sec
# Solving the linear relaxation with k=1
# Set parameter LogToConsole to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 201 rows, 19900 columns and 59700 nonzeros (Min)
# Model fingerprint: 0x4b7fc7c9
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+02]
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.03s
# Presolved: 200 rows, 19900 columns, 39800 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.990e+04
#  Factor NZ  : 2.010e+04 (roughly 8 MB of memory)
#  Factor Ops : 2.687e+06 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.05 seconds (0.03 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      288    9.8385000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 288 iterations and 0.08 seconds (0.04 work units)
# Optimal objective  9.838500000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 202 rows, 19900 columns and 60291 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.8385000e+03   1.000000e+00   0.000000e+00      0s
#        2    9.8510000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.851000000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 203 rows, 19900 columns and 60882 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.8510000e+03   1.000000e+00   0.000000e+00      0s
#        4    9.8582500e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 4 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.858250000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 204 rows, 19900 columns and 61473 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.8582500e+03   1.000000e+00   0.000000e+00      0s
#        2    9.8707500e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.870750000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 205 rows, 19900 columns and 62448 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.8707500e+03   1.000000e+00   0.000000e+00      0s
#        1    9.8805000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.880500000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 206 rows, 19900 columns and 63039 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.8805000e+03   1.000000e+00   0.000000e+00      0s
#        1    9.8970000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.897000000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 207 rows, 19900 columns and 64758 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.8970000e+03   1.000000e+00   0.000000e+00      0s
#        2    9.9030000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.903000000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 208 rows, 19900 columns and 65349 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9030000e+03   1.000000e+00   0.000000e+00      0s
#        2    9.9045000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.904500000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 209 rows, 19900 columns and 65940 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9045000e+03   1.000000e+00   0.000000e+00      0s
#        4    9.9377500e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 4 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.937750000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 210 rows, 19900 columns and 68196 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9377500e+03   1.000000e+00   0.000000e+00      0s
#        3    9.9445000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.944500000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 211 rows, 19900 columns and 68787 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9445000e+03   1.000000e+00   0.000000e+00      0s
#        5    9.9560000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.956000000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 212 rows, 19900 columns and 69571 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9560000e+03   1.000000e+00   0.000000e+00      0s
#        8    9.9625000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.962500000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 213 rows, 19900 columns and 70162 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9625000e+03   1.000000e+00   0.000000e+00      0s
#        1    9.9740000e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  9.974000000e+03
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 214 rows, 19900 columns and 71137 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.9740000e+03   1.000000e+00   0.000000e+00      0s
#        4    1.0002000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 4 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.000200000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 215 rows, 19900 columns and 73393 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0002000e+04   1.000000e+00   0.000000e+00      0s
#        3    1.0007500e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.000750000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 216 rows, 19900 columns and 77464 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0007500e+04   1.000000e+00   0.000000e+00      0s
#        8    1.0020500e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.002050000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 217 rows, 19900 columns and 80408 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0020500e+04   1.000000e+00   0.000000e+00      0s
#        3    1.0026000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.002600000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 218 rows, 19900 columns and 80999 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0026000e+04   1.000000e+00   0.000000e+00      0s
#        1    1.0036750e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.003675000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 219 rows, 19900 columns and 81590 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0036750e+04   1.000000e+00   0.000000e+00      0s
#        9    1.0082000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.008200000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 220 rows, 19900 columns and 82181 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0082000e+04   1.000000e+00   0.000000e+00      0s
#        3    1.0096000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.009600000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 221 rows, 19900 columns and 82772 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0096000e+04   1.000000e+00   0.000000e+00      0s
#        3    1.0097000e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.009700000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 222 rows, 19900 columns and 92763 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0097000e+04   1.000000e+00   0.000000e+00      0s
#        6    1.0099750e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 6 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.009975000e+04
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (linux64 - "Ubuntu 22.04.5 LTS")
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1360P, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Optimize a model with 223 rows, 19900 columns and 96202 nonzeros (Min)
# Model has 19900 linear objective coefficients
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e+00, 1e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+02]
# LP warm-start: use basis
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0099750e+04   1.000000e+00   0.000000e+00      0s
#        2    1.0099917e+04   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.009991667e+04
# Objective value: 10769.0, Linear relaxation k=2 value: 10484.25, Overlap: 181/200
# Objective value: 10769.0, Linear relaxation k=1 value: 10099.916666666666, Overlap: 167/200
# There are now 20 samples

# %%
for i, (objective_value, linear_relaxation_value, overlap) in enumerate(samples):
    print(
        f"Sample {i}: Objective value: {objective_value}, Linear relaxation value (>=2): {linear_relaxation_value}, Overlap: {overlap}/{n}, IGap: {objective_value/linear_relaxation_value}, Gap: {round(linear_relaxation_value/objective_value, 2)}%"
    )
# Out:
# Sample 0: Objective value: 11212.0, Linear relaxation value (>=2): 11110.5, Overlap: 180/200, IGap: 1.009135502452635, Gap: 0.99%
# Sample 1: Objective value: 10561.0, Linear relaxation value (>=2): 10438.5, Overlap: 179/200, IGap: 1.0117354025961585, Gap: 0.99%
# Sample 2: Objective value: 10747.0, Linear relaxation value (>=2): 10605.083333333334, Overlap: 169/200, IGap: 1.013381947336576, Gap: 0.99%
# Sample 3: Objective value: 10984.0, Linear relaxation value (>=2): 10551.75, Overlap: 157/200, IGap: 1.0409647688772006, Gap: 0.96%
# Sample 4: Objective value: 10711.0, Linear relaxation value (>=2): 10536.083333333332, Overlap: 168/200, IGap: 1.0166016783592893, Gap: 0.98%
# Sample 5: Objective value: 10739.0, Linear relaxation value (>=2): 10576.5, Overlap: 174/200, IGap: 1.0153642509336738, Gap: 0.98%
# Sample 6: Objective value: 10509.0, Linear relaxation value (>=2): 10369.833333333332, Overlap: 182/200, IGap: 1.013420337838924, Gap: 0.99%
# Sample 7: Objective value: 10599.0, Linear relaxation value (>=2): 10414.5, Overlap: 182/200, IGap: 1.0177156848624513, Gap: 0.98%
# Sample 8: Objective value: 10732.0, Linear relaxation value (>=2): 10530.75, Overlap: 178/200, IGap: 1.019110699617786, Gap: 0.98%
# Sample 9: Objective value: 10732.0, Linear relaxation value (>=2): 10556.625, Overlap: 171/200, IGap: 1.016612790546221, Gap: 0.98%
# Sample 10: Objective value: 10623.0, Linear relaxation value (>=2): 10491.5, Overlap: 184/200, IGap: 1.0125339560596673, Gap: 0.99%
# Sample 11: Objective value: 20267.0, Linear relaxation value (>=2): 10659.5, Overlap: 71/200, IGap: 1.901308691777288, Gap: 0.53%
# Sample 12: Objective value: 10874.0, Linear relaxation value (>=2): 10708.25, Overlap: 177/200, IGap: 1.0154787196787525, Gap: 0.98%
# Sample 13: Objective value: 10295.0, Linear relaxation value (>=2): 10098.5, Overlap: 178/200, IGap: 1.019458335396346, Gap: 0.98%
# Sample 14: Objective value: 11065.0, Linear relaxation value (>=2): 10913.583333333336, Overlap: 182/200, IGap: 1.013874147660026, Gap: 0.99%
# Sample 15: Objective value: 10675.0, Linear relaxation value (>=2): 10295.0, Overlap: 179/200, IGap: 1.0369111219038367, Gap: 0.96%
# Sample 16: Objective value: 10631.0, Linear relaxation value (>=2): 10446.333333333336, Overlap: 172/200, IGap: 1.0176776540412902, Gap: 0.98%
# Sample 17: Objective value: 10702.0, Linear relaxation value (>=2): 10525.0, Overlap: 173/200, IGap: 1.0168171021377672, Gap: 0.98%
# Sample 18: Objective value: 11139.0, Linear relaxation value (>=2): 10938.5, Overlap: 178/200, IGap: 1.0183297527083237, Gap: 0.98%
# Sample 19: Objective value: 10769.0, Linear relaxation value (>=2): 10484.25, Overlap: 181/200, IGap: 1.0271597872999976, Gap: 0.97%
